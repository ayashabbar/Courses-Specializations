# %% [markdown]
# # Ungraded Lab: Build a Multi-output Model
#
# In this lab, we'll show how you can build models with more than one output. The dataset we will be working on is available from the [UCI Machine Learning Repository](https://archive.ics.uci.edu/ml/datasets/Energy+efficiency). It is an Energy Efficiency dataset which uses the bulding features (e.g. wall area, roof area) as inputs and has two outputs: Cooling Load and Heating Load. Let's see how we can build a model to train on this data.

# %% [markdown]
# ## Imports

# %%
try:
  # %tensorflow_version only exists in Colab.
  # %tensorflow_version 2.x
except Exception:
  pass

import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Input
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Utilities
#
# We define a few utilities for data conversion and visualization to make our code more neat.

# %%
def format_output(data):
    y1 = data.pop('Y1')
    y1 = np.array(y1)
    y2 = data.pop('Y2')
    y2 = np.array(y2)
    return y1, y2


def norm(x):
    return (x - train_stats['mean']) / train_stats['std']


def plot_diff(y_true, y_pred, title=''):
    plt.scatter(y_true, y_pred)
    plt.title(title)
    plt.xlabel('True Values')
    plt.ylabel('Predictions')
    plt.axis('equal')
    plt.axis('square')
    plt.xlim(plt.xlim())
    plt.ylim(plt.ylim())
    plt.plot([-100, 100], [-100, 100])
    plt.show()


def plot_metrics(metric_name, title, ylim=5):
    plt.title(title)
    plt.ylim(0, ylim)
    plt.plot(history.history[metric_name], color='blue', label=metric_name)
    plt.plot(history.history['val_' + metric_name], color='green', label='val_' + metric_name)
    plt.show()

# %% [markdown]
# ## Prepare the Data
#
# We download the dataset and format it for training.

# %%
# Specify data URI
URI = './data/ENB2012_data.xlsx'

# Use pandas excel reader
df = pd.read_excel(URI)
df = df.sample(frac=1).reset_index(drop=True)

# Split the data into train and test with 80 train / 20 test
train, test = train_test_split(df, test_size=0.2)
train_stats = train.describe()

# Get Y1 and Y2 as the 2 outputs and format them as np arrays
train_stats.pop('Y1')
train_stats.pop('Y2')
train_stats = train_stats.transpose()
train_Y = format_output(train)
test_Y = format_output(test)

# Normalize the training and test data
norm_train_X = norm(train)
norm_test_X = norm(test)

# %% [markdown]
# ## Build the Model
#
# Here is how we'll build the model using the functional syntax. Notice that we can specify a list of outputs (i.e. `[y1_output, y2_output]`) when we instantiate the `Model()` class.

# %%
# Define model layers.
input_layer = Input(shape=(len(train .columns),))
first_dense = Dense(units='128', activation='relu')(input_layer)
second_dense = Dense(units='128', activation='relu')(first_dense)

# Y1 output will be fed directly from the second dense
y1_output = Dense(units='1', name='y1_output')(second_dense)
third_dense = Dense(units='64', activation='relu')(second_dense)

# Y2 output will come via the third dense
y2_output = Dense(units='1', name='y2_output')(third_dense)

# Define the model with the input layer and a list of output layers
model = Model(inputs=input_layer, outputs=[y1_output, y2_output])

print(model.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 8)]          0
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 128)          1152        input_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 128)          16512       dense[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 64)           8256        dense_1[0][0]
# __________________________________________________________________________________________________
# y1_output (Dense)               (None, 1)            129         dense_1[0][0]
# __________________________________________________________________________________________________
# y2_output (Dense)               (None, 1)            65          dense_2[0][0]
# ==================================================================================================
# Total params: 26,114
# Trainable params: 26,114
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %% [markdown]
# ## Configure parameters
#
# We specify the optimizer as well as the loss and metrics for each output.

# %%
# Specify the optimizer, and compile the model with loss functions for both outputs
optimizer = tf.keras.optimizers.SGD(lr=0.001)
model.compile(optimizer=optimizer,
              loss={'y1_output': 'mse', 'y2_output': 'mse'},
              metrics={'y1_output': tf.keras.metrics.RootMeanSquaredError(),
                       'y2_output': tf.keras.metrics.RootMeanSquaredError()})

# %% [markdown]
# ## Train the Model

# %%
# Train the model for 500 epochs
history = model.fit(norm_train_X, train_Y,
                    epochs=500, batch_size=10, validation_data=(norm_test_X, test_Y))
# Out:
# Train on 614 samples, validate on 154 samples
# Epoch 1/500
# 614/614 [==============================] - 1s 1ms/sample - loss: 224.3976 - y1_output_loss: 108.2954 - y2_output_loss: 114.1478 - y1_output_root_mean_squared_error: 10.4490 - y2_output_root_mean_squared_error: 10.7339 - val_loss: 62.5886 - val_y1_output_loss: 28.6864 - val_y2_output_loss: 35.2879 - val_y1_output_root_mean_squared_error: 5.2947 - val_y2_output_root_mean_squared_error: 5.8783
# Epoch 2/500
# 614/614 [==============================] - 0s 191us/sample - loss: 30.2131 - y1_output_loss: 12.0987 - y2_output_loss: 18.0081 - y1_output_root_mean_squared_error: 3.4805 - y2_output_root_mean_squared_error: 4.2543 - val_loss: 39.2687 - val_y1_output_loss: 10.9080 - val_y2_output_loss: 28.0723 - val_y1_output_root_mean_squared_error: 3.3517 - val_y2_output_root_mean_squared_error: 5.2948
# Epoch 3/500
# 614/614 [==============================] - 0s 170us/sample - loss: 24.9010 - y1_output_loss: 9.8976 - y2_output_loss: 15.0030 - y1_output_root_mean_squared_error: 3.1309 - y2_output_root_mean_squared_error: 3.8857 - val_loss: 32.5479 - val_y1_output_loss: 15.3524 - val_y2_output_loss: 16.5160 - val_y1_output_root_mean_squared_error: 3.9613 - val_y2_output_root_mean_squared_error: 4.1056
# Epoch 4/500
# 614/614 [==============================] - 0s 183us/sample - loss: 23.6916 - y1_output_loss: 9.3960 - y2_output_loss: 14.1223 - y1_output_root_mean_squared_error: 3.0780 - y2_output_root_mean_squared_error: 3.7706 - val_loss: 23.3092 - val_y1_output_loss: 10.0043 - val_y2_output_loss: 12.7123 - val_y1_output_root_mean_squared_error: 3.2029 - val_y2_output_root_mean_squared_error: 3.6126
# Epoch 5/500
# 614/614 [==============================] - 0s 162us/sample - loss: 23.7153 - y1_output_loss: 9.0541 - y2_output_loss: 14.5589 - y1_output_root_mean_squared_error: 3.0181 - y2_output_root_mean_squared_error: 3.8218 - val_loss: 22.9054 - val_y1_output_loss: 9.0096 - val_y2_output_loss: 13.5516 - val_y1_output_root_mean_squared_error: 3.0416 - val_y2_output_root_mean_squared_error: 3.6951
# Epoch 6/500
# 614/614 [==============================] - 0s 154us/sample - loss: 25.4318 - y1_output_loss: 9.0730 - y2_output_loss: 16.2021 - y1_output_root_mean_squared_error: 3.0221 - y2_output_root_mean_squared_error: 4.0372 - val_loss: 30.0856 - val_y1_output_loss: 8.6998 - val_y2_output_loss: 21.0444 - val_y1_output_root_mean_squared_error: 3.0024 - val_y2_output_root_mean_squared_error: 4.5904
# Epoch 7/500
# 614/614 [==============================] - 0s 172us/sample - loss: 20.3834 - y1_output_loss: 8.5354 - y2_output_loss: 12.1248 - y1_output_root_mean_squared_error: 2.9129 - y2_output_root_mean_squared_error: 3.4494 - val_loss: 65.7222 - val_y1_output_loss: 16.3031 - val_y2_output_loss: 49.0215 - val_y1_output_root_mean_squared_error: 4.0678 - val_y2_output_root_mean_squared_error: 7.0125
# Epoch 8/500
# 614/614 [==============================] - 0s 164us/sample - loss: 20.7214 - y1_output_loss: 8.2467 - y2_output_loss: 12.4828 - y1_output_root_mean_squared_error: 2.8741 - y2_output_root_mean_squared_error: 3.5300 - val_loss: 76.9888 - val_y1_output_loss: 17.9028 - val_y2_output_loss: 59.4878 - val_y1_output_root_mean_squared_error: 4.2293 - val_y2_output_root_mean_squared_error: 7.6878
# Epoch 9/500
# 614/614 [==============================] - 0s 164us/sample - loss: 23.5290 - y1_output_loss: 9.0437 - y2_output_loss: 15.1246 - y1_output_root_mean_squared_error: 2.9949 - y2_output_root_mean_squared_error: 3.8157 - val_loss: 30.2937 - val_y1_output_loss: 12.5098 - val_y2_output_loss: 17.0277 - val_y1_output_root_mean_squared_error: 3.5937 - val_y2_output_root_mean_squared_error: 4.1688
# Epoch 10/500
# 614/614 [==============================] - 0s 175us/sample - loss: 23.0878 - y1_output_loss: 8.6834 - y2_output_loss: 14.1952 - y1_output_root_mean_squared_error: 2.9602 - y2_output_root_mean_squared_error: 3.7848 - val_loss: 19.8473 - val_y1_output_loss: 7.7052 - val_y2_output_loss: 11.5890 - val_y1_output_root_mean_squared_error: 2.8258 - val_y2_output_root_mean_squared_error: 3.4442
# Epoch 11/500
# 614/614 [==============================] - 0s 156us/sample - loss: 23.6725 - y1_output_loss: 8.8169 - y2_output_loss: 14.6995 - y1_output_root_mean_squared_error: 2.9765 - y2_output_root_mean_squared_error: 3.8488 - val_loss: 22.8270 - val_y1_output_loss: 9.5492 - val_y2_output_loss: 12.7919 - val_y1_output_root_mean_squared_error: 3.1250 - val_y2_output_root_mean_squared_error: 3.6140
# Epoch 12/500
# 614/614 [==============================] - 0s 154us/sample - loss: 20.8521 - y1_output_loss: 8.0451 - y2_output_loss: 13.9267 - y1_output_root_mean_squared_error: 2.8120 - y2_output_root_mean_squared_error: 3.5979 - val_loss: 260.2297 - val_y1_output_loss: 41.5331 - val_y2_output_loss: 219.7710 - val_y1_output_root_mean_squared_error: 6.4520 - val_y2_output_root_mean_squared_error: 14.7852
# Epoch 13/500
# 614/614 [==============================] - 0s 159us/sample - loss: 33.7862 - y1_output_loss: 9.9566 - y2_output_loss: 23.5603 - y1_output_root_mean_squared_error: 3.1686 - y2_output_root_mean_squared_error: 4.8730 - val_loss: 19.2494 - val_y1_output_loss: 7.7240 - val_y2_output_loss: 10.9397 - val_y1_output_root_mean_squared_error: 2.8286 - val_y2_output_root_mean_squared_error: 3.3539
# Epoch 14/500
# 614/614 [==============================] - 0s 164us/sample - loss: 18.7669 - y1_output_loss: 7.4371 - y2_output_loss: 11.1736 - y1_output_root_mean_squared_error: 2.7398 - y2_output_root_mean_squared_error: 3.3556 - val_loss: 21.3066 - val_y1_output_loss: 9.1503 - val_y2_output_loss: 11.6709 - val_y1_output_root_mean_squared_error: 3.0691 - val_y2_output_root_mean_squared_error: 3.4478
# Epoch 15/500
# 614/614 [==============================] - 0s 175us/sample - loss: 16.3501 - y1_output_loss: 6.6410 - y2_output_loss: 9.8741 - y1_output_root_mean_squared_error: 2.5697 - y2_output_root_mean_squared_error: 3.1219 - val_loss: 38.7368 - val_y1_output_loss: 12.8352 - val_y2_output_loss: 25.6715 - val_y1_output_root_mean_squared_error: 3.5956 - val_y2_output_root_mean_squared_error: 5.0802
# Epoch 16/500
# 614/614 [==============================] - 0s 157us/sample - loss: 18.1017 - y1_output_loss: 7.1542 - y2_output_loss: 11.1927 - y1_output_root_mean_squared_error: 2.6616 - y2_output_root_mean_squared_error: 3.3193 - val_loss: 17.6830 - val_y1_output_loss: 6.4589 - val_y2_output_loss: 11.0175 - val_y1_output_root_mean_squared_error: 2.5665 - val_y2_output_root_mean_squared_error: 3.3310
# Epoch 17/500
# 614/614 [==============================] - 0s 148us/sample - loss: 16.3670 - y1_output_loss: 6.3492 - y2_output_loss: 9.9986 - y1_output_root_mean_squared_error: 2.5229 - y2_output_root_mean_squared_error: 3.1626 - val_loss: 17.9121 - val_y1_output_loss: 6.6162 - val_y2_output_loss: 10.7545 - val_y1_output_root_mean_squared_error: 2.6116 - val_y2_output_root_mean_squared_error: 3.3304
# Epoch 18/500
# 614/614 [==============================] - 0s 161us/sample - loss: 15.4081 - y1_output_loss: 6.0177 - y2_output_loss: 9.4095 - y1_output_root_mean_squared_error: 2.4496 - y2_output_root_mean_squared_error: 3.0672 - val_loss: 34.4443 - val_y1_output_loss: 10.4221 - val_y2_output_loss: 23.9993 - val_y1_output_root_mean_squared_error: 3.2380 - val_y2_output_root_mean_squared_error: 4.8949
# Epoch 19/500
# 614/614 [==============================] - 0s 170us/sample - loss: 18.0252 - y1_output_loss: 6.7750 - y2_output_loss: 11.1578 - y1_output_root_mean_squared_error: 2.6071 - y2_output_root_mean_squared_error: 3.3509 - val_loss: 14.5934 - val_y1_output_loss: 5.4632 - val_y2_output_loss: 8.6933 - val_y1_output_root_mean_squared_error: 2.3751 - val_y2_output_root_mean_squared_error: 2.9920
# Epoch 20/500
# 614/614 [==============================] - 0s 177us/sample - loss: 16.9845 - y1_output_loss: 6.2043 - y2_output_loss: 10.8480 - y1_output_root_mean_squared_error: 2.4957 - y2_output_root_mean_squared_error: 3.2796 - val_loss: 25.2182 - val_y1_output_loss: 8.3297 - val_y2_output_loss: 16.6744 - val_y1_output_root_mean_squared_error: 2.9029 - val_y2_output_root_mean_squared_error: 4.0978
# Epoch 21/500
# 614/614 [==============================] - 0s 173us/sample - loss: 14.0390 - y1_output_loss: 5.5373 - y2_output_loss: 8.4170 - y1_output_root_mean_squared_error: 2.3611 - y2_output_root_mean_squared_error: 2.9093 - val_loss: 22.2757 - val_y1_output_loss: 7.4416 - val_y2_output_loss: 14.5367 - val_y1_output_root_mean_squared_error: 2.7497 - val_y2_output_root_mean_squared_error: 3.8360
# Epoch 22/500
# 614/614 [==============================] - 0s 152us/sample - loss: 14.9578 - y1_output_loss: 5.4489 - y2_output_loss: 9.4717 - y1_output_root_mean_squared_error: 2.3438 - y2_output_root_mean_squared_error: 3.0764 - val_loss: 18.3459 - val_y1_output_loss: 5.6098 - val_y2_output_loss: 12.4688 - val_y1_output_root_mean_squared_error: 2.3923 - val_y2_output_root_mean_squared_error: 3.5528
# Epoch 23/500
# 614/614 [==============================] - 0s 160us/sample - loss: 12.3660 - y1_output_loss: 4.9587 - y2_output_loss: 7.5104 - y1_output_root_mean_squared_error: 2.2307 - y2_output_root_mean_squared_error: 2.7185 - val_loss: 53.9780 - val_y1_output_loss: 8.7151 - val_y2_output_loss: 45.2851 - val_y1_output_root_mean_squared_error: 2.9617 - val_y2_output_root_mean_squared_error: 6.7236
# Epoch 24/500
# 614/614 [==============================] - 0s 162us/sample - loss: 15.2440 - y1_output_loss: 5.2231 - y2_output_loss: 9.8807 - y1_output_root_mean_squared_error: 2.2957 - y2_output_root_mean_squared_error: 3.1581 - val_loss: 13.9998 - val_y1_output_loss: 4.5708 - val_y2_output_loss: 9.2283 - val_y1_output_root_mean_squared_error: 2.1659 - val_y2_output_root_mean_squared_error: 3.0510
# Epoch 25/500
# 614/614 [==============================] - 0s 163us/sample - loss: 12.2122 - y1_output_loss: 4.5365 - y2_output_loss: 7.6050 - y1_output_root_mean_squared_error: 2.1374 - y2_output_root_mean_squared_error: 2.7647 - val_loss: 11.8089 - val_y1_output_loss: 4.0514 - val_y2_output_loss: 7.4018 - val_y1_output_root_mean_squared_error: 2.0475 - val_y2_output_root_mean_squared_error: 2.7598
# Epoch 26/500
# 614/614 [==============================] - 0s 164us/sample - loss: 10.5304 - y1_output_loss: 4.1991 - y2_output_loss: 6.3687 - y1_output_root_mean_squared_error: 2.0387 - y2_output_root_mean_squared_error: 2.5247 - val_loss: 30.5476 - val_y1_output_loss: 9.0086 - val_y2_output_loss: 21.4737 - val_y1_output_root_mean_squared_error: 3.0160 - val_y2_output_root_mean_squared_error: 4.6316
# Epoch 27/500
# 614/614 [==============================] - 0s 153us/sample - loss: 12.8837 - y1_output_loss: 4.4428 - y2_output_loss: 8.4873 - y1_output_root_mean_squared_error: 2.1130 - y2_output_root_mean_squared_error: 2.9015 - val_loss: 24.0705 - val_y1_output_loss: 5.8926 - val_y2_output_loss: 17.6208 - val_y1_output_root_mean_squared_error: 2.4673 - val_y2_output_root_mean_squared_error: 4.2406
# Epoch 28/500
# 614/614 [==============================] - 0s 149us/sample - loss: 11.0463 - y1_output_loss: 4.3043 - y2_output_loss: 6.7347 - y1_output_root_mean_squared_error: 2.0803 - y2_output_root_mean_squared_error: 2.5920 - val_loss: 17.1194 - val_y1_output_loss: 5.2695 - val_y2_output_loss: 11.5997 - val_y1_output_root_mean_squared_error: 2.3282 - val_y2_output_root_mean_squared_error: 3.4204
# Epoch 29/500
# 614/614 [==============================] - 0s 160us/sample - loss: 11.5820 - y1_output_loss: 4.0592 - y2_output_loss: 7.5279 - y1_output_root_mean_squared_error: 2.0177 - y2_output_root_mean_squared_error: 2.7406 - val_loss: 10.8395 - val_y1_output_loss: 3.6758 - val_y2_output_loss: 6.8414 - val_y1_output_root_mean_squared_error: 1.9506 - val_y2_output_root_mean_squared_error: 2.6523
# Epoch 30/500
# 614/614 [==============================] - 0s 156us/sample - loss: 9.8015 - y1_output_loss: 3.5268 - y2_output_loss: 6.2844 - y1_output_root_mean_squared_error: 1.8834 - y2_output_root_mean_squared_error: 2.5009 - val_loss: 14.0635 - val_y1_output_loss: 5.4538 - val_y2_output_loss: 8.2719 - val_y1_output_root_mean_squared_error: 2.3617 - val_y2_output_root_mean_squared_error: 2.9130
# Epoch 31/500
# 614/614 [==============================] - 0s 152us/sample - loss: 10.6138 - y1_output_loss: 3.9224 - y2_output_loss: 6.7243 - y1_output_root_mean_squared_error: 1.9626 - y2_output_root_mean_squared_error: 2.6004 - val_loss: 16.7470 - val_y1_output_loss: 4.9164 - val_y2_output_loss: 11.8189 - val_y1_output_root_mean_squared_error: 2.2357 - val_y2_output_root_mean_squared_error: 3.4277
# Epoch 32/500
# 614/614 [==============================] - 0s 176us/sample - loss: 9.0306 - y1_output_loss: 3.0820 - y2_output_loss: 5.8922 - y1_output_root_mean_squared_error: 1.7619 - y2_output_root_mean_squared_error: 2.4344 - val_loss: 12.7860 - val_y1_output_loss: 3.6153 - val_y2_output_loss: 8.8634 - val_y1_output_root_mean_squared_error: 1.9261 - val_y2_output_root_mean_squared_error: 3.0127
# Epoch 33/500
# 614/614 [==============================] - 0s 156us/sample - loss: 8.6587 - y1_output_loss: 2.8317 - y2_output_loss: 5.7806 - y1_output_root_mean_squared_error: 1.6874 - y2_output_root_mean_squared_error: 2.4107 - val_loss: 19.5481 - val_y1_output_loss: 4.6011 - val_y2_output_loss: 14.9791 - val_y1_output_root_mean_squared_error: 2.1614 - val_y2_output_root_mean_squared_error: 3.8570
# Epoch 34/500
# 614/614 [==============================] - 0s 163us/sample - loss: 7.5909 - y1_output_loss: 2.8860 - y2_output_loss: 4.6632 - y1_output_root_mean_squared_error: 1.7032 - y2_output_root_mean_squared_error: 2.1657 - val_loss: 12.1296 - val_y1_output_loss: 4.5986 - val_y2_output_loss: 7.2601 - val_y1_output_root_mean_squared_error: 2.1670 - val_y2_output_root_mean_squared_error: 2.7264
# Epoch 35/500
# 614/614 [==============================] - 0s 176us/sample - loss: 9.7086 - y1_output_loss: 3.3565 - y2_output_loss: 6.3174 - y1_output_root_mean_squared_error: 1.8255 - y2_output_root_mean_squared_error: 2.5251 - val_loss: 10.9929 - val_y1_output_loss: 3.9676 - val_y2_output_loss: 6.8376 - val_y1_output_root_mean_squared_error: 2.0039 - val_y2_output_root_mean_squared_error: 2.6414
# Epoch 36/500
# 614/614 [==============================] - 0s 163us/sample - loss: 8.4760 - y1_output_loss: 2.7670 - y2_output_loss: 5.7821 - y1_output_root_mean_squared_error: 1.6539 - y2_output_root_mean_squared_error: 2.3960 - val_loss: 8.5710 - val_y1_output_loss: 2.6823 - val_y2_output_loss: 5.7062 - val_y1_output_root_mean_squared_error: 1.6626 - val_y2_output_root_mean_squared_error: 2.4097
# Epoch 37/500
# 614/614 [==============================] - 0s 171us/sample - loss: 8.1075 - y1_output_loss: 2.7643 - y2_output_loss: 5.3867 - y1_output_root_mean_squared_error: 1.6625 - y2_output_root_mean_squared_error: 2.3116 - val_loss: 13.2781 - val_y1_output_loss: 4.1613 - val_y2_output_loss: 8.8988 - val_y1_output_root_mean_squared_error: 2.0543 - val_y2_output_root_mean_squared_error: 3.0096
# Epoch 38/500
# 614/614 [==============================] - 0s 165us/sample - loss: 7.3783 - y1_output_loss: 2.5099 - y2_output_loss: 4.8225 - y1_output_root_mean_squared_error: 1.5886 - y2_output_root_mean_squared_error: 2.2033 - val_loss: 10.3478 - val_y1_output_loss: 2.8305 - val_y2_output_loss: 7.3886 - val_y1_output_root_mean_squared_error: 1.6984 - val_y2_output_root_mean_squared_error: 2.7319
# Epoch 39/500
# 614/614 [==============================] - 0s 159us/sample - loss: 6.5342 - y1_output_loss: 2.3716 - y2_output_loss: 4.1858 - y1_output_root_mean_squared_error: 1.5329 - y2_output_root_mean_squared_error: 2.0456 - val_loss: 14.1349 - val_y1_output_loss: 4.8945 - val_y2_output_loss: 8.8337 - val_y1_output_root_mean_squared_error: 2.2482 - val_y2_output_root_mean_squared_error: 3.0134
# Epoch 40/500
# 614/614 [==============================] - 0s 156us/sample - loss: 8.1258 - y1_output_loss: 2.6209 - y2_output_loss: 5.4640 - y1_output_root_mean_squared_error: 1.6266 - y2_output_root_mean_squared_error: 2.3409 - val_loss: 10.6851 - val_y1_output_loss: 3.7901 - val_y2_output_loss: 6.8512 - val_y1_output_root_mean_squared_error: 1.9572 - val_y2_output_root_mean_squared_error: 2.6181
# Epoch 41/500
# 614/614 [==============================] - 0s 159us/sample - loss: 6.7631 - y1_output_loss: 2.4373 - y2_output_loss: 4.3338 - y1_output_root_mean_squared_error: 1.5536 - y2_output_root_mean_squared_error: 2.0855 - val_loss: 10.2565 - val_y1_output_loss: 3.7331 - val_y2_output_loss: 6.3614 - val_y1_output_root_mean_squared_error: 1.9500 - val_y2_output_root_mean_squared_error: 2.5405
# Epoch 42/500
# 614/614 [==============================] - 0s 153us/sample - loss: 6.8363 - y1_output_loss: 2.2387 - y2_output_loss: 4.6715 - y1_output_root_mean_squared_error: 1.4963 - y2_output_root_mean_squared_error: 2.1442 - val_loss: 8.4968 - val_y1_output_loss: 3.1990 - val_y2_output_loss: 5.2989 - val_y1_output_root_mean_squared_error: 1.7866 - val_y2_output_root_mean_squared_error: 2.3032
# Epoch 43/500
# 614/614 [==============================] - 0s 174us/sample - loss: 6.7868 - y1_output_loss: 2.3660 - y2_output_loss: 4.4456 - y1_output_root_mean_squared_error: 1.5450 - y2_output_root_mean_squared_error: 2.0976 - val_loss: 10.1687 - val_y1_output_loss: 2.5803 - val_y2_output_loss: 7.4863 - val_y1_output_root_mean_squared_error: 1.6289 - val_y2_output_root_mean_squared_error: 2.7414
# Epoch 44/500
# 614/614 [==============================] - 0s 157us/sample - loss: 6.9023 - y1_output_loss: 2.2613 - y2_output_loss: 4.6404 - y1_output_root_mean_squared_error: 1.5050 - y2_output_root_mean_squared_error: 2.1534 - val_loss: 10.0358 - val_y1_output_loss: 2.7169 - val_y2_output_loss: 7.2360 - val_y1_output_root_mean_squared_error: 1.6695 - val_y2_output_root_mean_squared_error: 2.6923
# Epoch 45/500
# 614/614 [==============================] - 0s 167us/sample - loss: 7.4349 - y1_output_loss: 2.3251 - y2_output_loss: 5.0869 - y1_output_root_mean_squared_error: 1.5269 - y2_output_root_mean_squared_error: 2.2591 - val_loss: 21.0906 - val_y1_output_loss: 5.2432 - val_y2_output_loss: 16.0504 - val_y1_output_root_mean_squared_error: 2.2743 - val_y2_output_root_mean_squared_error: 3.9898
# Epoch 46/500
# 614/614 [==============================] - 0s 164us/sample - loss: 7.7096 - y1_output_loss: 2.3666 - y2_output_loss: 5.3632 - y1_output_root_mean_squared_error: 1.5392 - y2_output_root_mean_squared_error: 2.3110 - val_loss: 29.6226 - val_y1_output_loss: 5.9881 - val_y2_output_loss: 24.0618 - val_y1_output_root_mean_squared_error: 2.4418 - val_y2_output_root_mean_squared_error: 4.8642
# Epoch 47/500
# 614/614 [==============================] - 0s 152us/sample - loss: 6.6908 - y1_output_loss: 2.1143 - y2_output_loss: 4.5243 - y1_output_root_mean_squared_error: 1.4601 - y2_output_root_mean_squared_error: 2.1352 - val_loss: 9.2002 - val_y1_output_loss: 3.3222 - val_y2_output_loss: 5.8137 - val_y1_output_root_mean_squared_error: 1.8278 - val_y2_output_root_mean_squared_error: 2.4206
# Epoch 48/500
# 614/614 [==============================] - 0s 163us/sample - loss: 6.3540 - y1_output_loss: 1.9622 - y2_output_loss: 4.3437 - y1_output_root_mean_squared_error: 1.4061 - y2_output_root_mean_squared_error: 2.0921 - val_loss: 7.3524 - val_y1_output_loss: 2.4425 - val_y2_output_loss: 4.9731 - val_y1_output_root_mean_squared_error: 1.5599 - val_y2_output_root_mean_squared_error: 2.2179
# Epoch 49/500
# 614/614 [==============================] - 0s 158us/sample - loss: 7.2865 - y1_output_loss: 2.1404 - y2_output_loss: 5.1232 - y1_output_root_mean_squared_error: 1.4667 - y2_output_root_mean_squared_error: 2.2661 - val_loss: 7.6659 - val_y1_output_loss: 2.2321 - val_y2_output_loss: 5.3588 - val_y1_output_root_mean_squared_error: 1.5121 - val_y2_output_root_mean_squared_error: 2.3194
# Epoch 50/500
# 614/614 [==============================] - 0s 148us/sample - loss: 6.0997 - y1_output_loss: 2.1162 - y2_output_loss: 4.0521 - y1_output_root_mean_squared_error: 1.4507 - y2_output_root_mean_squared_error: 1.9988 - val_loss: 12.2095 - val_y1_output_loss: 4.2974 - val_y2_output_loss: 8.3739 - val_y1_output_root_mean_squared_error: 2.0220 - val_y2_output_root_mean_squared_error: 2.8497
# Epoch 51/500
# 614/614 [==============================] - 0s 159us/sample - loss: 5.5546 - y1_output_loss: 1.8562 - y2_output_loss: 3.7335 - y1_output_root_mean_squared_error: 1.3641 - y2_output_root_mean_squared_error: 1.9219 - val_loss: 7.8326 - val_y1_output_loss: 2.2929 - val_y2_output_loss: 5.5040 - val_y1_output_root_mean_squared_error: 1.5291 - val_y2_output_root_mean_squared_error: 2.3440
# Epoch 52/500
# 614/614 [==============================] - 0s 161us/sample - loss: 5.9695 - y1_output_loss: 1.8808 - y2_output_loss: 4.0396 - y1_output_root_mean_squared_error: 1.3761 - y2_output_root_mean_squared_error: 2.0189 - val_loss: 7.0348 - val_y1_output_loss: 2.1725 - val_y2_output_loss: 4.7929 - val_y1_output_root_mean_squared_error: 1.4801 - val_y2_output_root_mean_squared_error: 2.2009
# Epoch 53/500
# 614/614 [==============================] - 0s 158us/sample - loss: 6.5264 - y1_output_loss: 2.0724 - y2_output_loss: 4.4510 - y1_output_root_mean_squared_error: 1.4412 - y2_output_root_mean_squared_error: 2.1093 - val_loss: 11.1019 - val_y1_output_loss: 2.5670 - val_y2_output_loss: 8.4233 - val_y1_output_root_mean_squared_error: 1.6135 - val_y2_output_root_mean_squared_error: 2.9152
# Epoch 54/500
# 614/614 [==============================] - 0s 177us/sample - loss: 6.8012 - y1_output_loss: 2.0668 - y2_output_loss: 4.7200 - y1_output_root_mean_squared_error: 1.4343 - y2_output_root_mean_squared_error: 2.1781 - val_loss: 8.5964 - val_y1_output_loss: 3.3676 - val_y2_output_loss: 5.2342 - val_y1_output_root_mean_squared_error: 1.8334 - val_y2_output_root_mean_squared_error: 2.2880
# Epoch 55/500
# 614/614 [==============================] - 0s 154us/sample - loss: 5.3184 - y1_output_loss: 1.5531 - y2_output_loss: 3.7740 - y1_output_root_mean_squared_error: 1.2474 - y2_output_root_mean_squared_error: 1.9397 - val_loss: 9.3588 - val_y1_output_loss: 3.3252 - val_y2_output_loss: 5.9425 - val_y1_output_root_mean_squared_error: 1.8393 - val_y2_output_root_mean_squared_error: 2.4445
# Epoch 56/500
# 614/614 [==============================] - 0s 155us/sample - loss: 13.2195 - y1_output_loss: 4.4949 - y2_output_loss: 8.5990 - y1_output_root_mean_squared_error: 2.1300 - y2_output_root_mean_squared_error: 2.9466 - val_loss: 6.9165 - val_y1_output_loss: 2.0982 - val_y2_output_loss: 4.7644 - val_y1_output_root_mean_squared_error: 1.4558 - val_y2_output_root_mean_squared_error: 2.1902
# Epoch 57/500
# 614/614 [==============================] - 0s 162us/sample - loss: 5.9875 - y1_output_loss: 1.8552 - y2_output_loss: 4.1443 - y1_output_root_mean_squared_error: 1.3613 - y2_output_root_mean_squared_error: 2.0333 - val_loss: 10.5612 - val_y1_output_loss: 4.2423 - val_y2_output_loss: 6.5062 - val_y1_output_root_mean_squared_error: 2.0320 - val_y2_output_root_mean_squared_error: 2.5362
# Epoch 58/500
# 614/614 [==============================] - 0s 149us/sample - loss: 6.0608 - y1_output_loss: 1.9102 - y2_output_loss: 4.1543 - y1_output_root_mean_squared_error: 1.3827 - y2_output_root_mean_squared_error: 2.0369 - val_loss: 7.5734 - val_y1_output_loss: 2.4681 - val_y2_output_loss: 5.0192 - val_y1_output_root_mean_squared_error: 1.5809 - val_y2_output_root_mean_squared_error: 2.2526
# Epoch 59/500
# 614/614 [==============================] - 0s 164us/sample - loss: 5.2129 - y1_output_loss: 1.6219 - y2_output_loss: 3.5689 - y1_output_root_mean_squared_error: 1.2735 - y2_output_root_mean_squared_error: 1.8951 - val_loss: 9.3432 - val_y1_output_loss: 3.4256 - val_y2_output_loss: 5.8903 - val_y1_output_root_mean_squared_error: 1.8537 - val_y2_output_root_mean_squared_error: 2.4304
# Epoch 60/500
# 614/614 [==============================] - 0s 173us/sample - loss: 6.0537 - y1_output_loss: 1.8450 - y2_output_loss: 4.2334 - y1_output_root_mean_squared_error: 1.3632 - y2_output_root_mean_squared_error: 2.0483 - val_loss: 9.8445 - val_y1_output_loss: 2.0900 - val_y2_output_loss: 7.7501 - val_y1_output_root_mean_squared_error: 1.4523 - val_y2_output_root_mean_squared_error: 2.7813
# Epoch 61/500
# 614/614 [==============================] - 0s 162us/sample - loss: 5.5504 - y1_output_loss: 1.6006 - y2_output_loss: 3.9844 - y1_output_root_mean_squared_error: 1.2652 - y2_output_root_mean_squared_error: 1.9874 - val_loss: 13.6645 - val_y1_output_loss: 4.5110 - val_y2_output_loss: 9.4621 - val_y1_output_root_mean_squared_error: 2.0876 - val_y2_output_root_mean_squared_error: 3.0506
# Epoch 62/500
# 614/614 [==============================] - 0s 162us/sample - loss: 5.3663 - y1_output_loss: 1.6653 - y2_output_loss: 3.7100 - y1_output_root_mean_squared_error: 1.2892 - y2_output_root_mean_squared_error: 1.9246 - val_loss: 7.4882 - val_y1_output_loss: 2.1452 - val_y2_output_loss: 5.2987 - val_y1_output_root_mean_squared_error: 1.4840 - val_y2_output_root_mean_squared_error: 2.2992
# Epoch 63/500
# 614/614 [==============================] - 0s 166us/sample - loss: 6.9535 - y1_output_loss: 2.2253 - y2_output_loss: 4.7579 - y1_output_root_mean_squared_error: 1.4774 - y2_output_root_mean_squared_error: 2.1842 - val_loss: 9.3019 - val_y1_output_loss: 3.2971 - val_y2_output_loss: 5.8594 - val_y1_output_root_mean_squared_error: 1.8451 - val_y2_output_root_mean_squared_error: 2.4285
# Epoch 64/500
# 614/614 [==============================] - 0s 151us/sample - loss: 7.0773 - y1_output_loss: 2.1182 - y2_output_loss: 4.9460 - y1_output_root_mean_squared_error: 1.4594 - y2_output_root_mean_squared_error: 2.2243 - val_loss: 7.1319 - val_y1_output_loss: 1.6918 - val_y2_output_loss: 5.3466 - val_y1_output_root_mean_squared_error: 1.3111 - val_y2_output_root_mean_squared_error: 2.3266
# Epoch 65/500
# 614/614 [==============================] - 0s 179us/sample - loss: 5.2378 - y1_output_loss: 1.5292 - y2_output_loss: 3.6985 - y1_output_root_mean_squared_error: 1.2386 - y2_output_root_mean_squared_error: 1.9245 - val_loss: 7.0531 - val_y1_output_loss: 2.2823 - val_y2_output_loss: 4.7865 - val_y1_output_root_mean_squared_error: 1.5071 - val_y2_output_root_mean_squared_error: 2.1868
# Epoch 66/500
# 614/614 [==============================] - 0s 151us/sample - loss: 5.1441 - y1_output_loss: 1.5409 - y2_output_loss: 3.6173 - y1_output_root_mean_squared_error: 1.2325 - y2_output_root_mean_squared_error: 1.9040 - val_loss: 6.0374 - val_y1_output_loss: 1.8756 - val_y2_output_loss: 4.1838 - val_y1_output_root_mean_squared_error: 1.3567 - val_y2_output_root_mean_squared_error: 2.0486
# Epoch 67/500
# 614/614 [==============================] - 0s 163us/sample - loss: 4.8183 - y1_output_loss: 1.3238 - y2_output_loss: 3.4754 - y1_output_root_mean_squared_error: 1.1533 - y2_output_root_mean_squared_error: 1.8677 - val_loss: 7.9978 - val_y1_output_loss: 1.6782 - val_y2_output_loss: 6.2475 - val_y1_output_root_mean_squared_error: 1.3137 - val_y2_output_root_mean_squared_error: 2.5044
# Epoch 68/500
# 614/614 [==============================] - 0s 167us/sample - loss: 4.8587 - y1_output_loss: 1.4447 - y2_output_loss: 3.3868 - y1_output_root_mean_squared_error: 1.2066 - y2_output_root_mean_squared_error: 1.8447 - val_loss: 5.7079 - val_y1_output_loss: 1.5839 - val_y2_output_loss: 4.0766 - val_y1_output_root_mean_squared_error: 1.2692 - val_y2_output_root_mean_squared_error: 2.0241
# Epoch 69/500
# 614/614 [==============================] - 0s 152us/sample - loss: 6.1457 - y1_output_loss: 1.6042 - y2_output_loss: 4.4959 - y1_output_root_mean_squared_error: 1.2711 - y2_output_root_mean_squared_error: 2.1284 - val_loss: 10.6132 - val_y1_output_loss: 2.7610 - val_y2_output_loss: 7.8214 - val_y1_output_root_mean_squared_error: 1.6767 - val_y2_output_root_mean_squared_error: 2.7932
# Epoch 70/500
# 614/614 [==============================] - 0s 155us/sample - loss: 4.7574 - y1_output_loss: 1.3066 - y2_output_loss: 3.4126 - y1_output_root_mean_squared_error: 1.1463 - y2_output_root_mean_squared_error: 1.8557 - val_loss: 5.4715 - val_y1_output_loss: 1.3459 - val_y2_output_loss: 4.0777 - val_y1_output_root_mean_squared_error: 1.1680 - val_y2_output_root_mean_squared_error: 2.0266
# Epoch 71/500
# 614/614 [==============================] - 0s 160us/sample - loss: 4.0122 - y1_output_loss: 1.2009 - y2_output_loss: 2.7750 - y1_output_root_mean_squared_error: 1.1008 - y2_output_root_mean_squared_error: 1.6734 - val_loss: 5.5441 - val_y1_output_loss: 1.6917 - val_y2_output_loss: 3.8207 - val_y1_output_root_mean_squared_error: 1.3066 - val_y2_output_root_mean_squared_error: 1.9588
# Epoch 72/500
# 614/614 [==============================] - 0s 149us/sample - loss: 5.5972 - y1_output_loss: 1.6969 - y2_output_loss: 3.9666 - y1_output_root_mean_squared_error: 1.2960 - y2_output_root_mean_squared_error: 1.9793 - val_loss: 11.1660 - val_y1_output_loss: 3.8924 - val_y2_output_loss: 7.2541 - val_y1_output_root_mean_squared_error: 1.9766 - val_y2_output_root_mean_squared_error: 2.6942
# Epoch 73/500
# 614/614 [==============================] - 0s 152us/sample - loss: 5.8331 - y1_output_loss: 1.6206 - y2_output_loss: 4.2048 - y1_output_root_mean_squared_error: 1.2783 - y2_output_root_mean_squared_error: 2.0492 - val_loss: 18.6294 - val_y1_output_loss: 4.1187 - val_y2_output_loss: 14.7961 - val_y1_output_root_mean_squared_error: 2.0093 - val_y2_output_root_mean_squared_error: 3.8200
# Epoch 74/500
# 614/614 [==============================] - 0s 167us/sample - loss: 4.4573 - y1_output_loss: 1.2301 - y2_output_loss: 3.2193 - y1_output_root_mean_squared_error: 1.1100 - y2_output_root_mean_squared_error: 1.7959 - val_loss: 7.2897 - val_y1_output_loss: 2.3006 - val_y2_output_loss: 4.8784 - val_y1_output_root_mean_squared_error: 1.5352 - val_y2_output_root_mean_squared_error: 2.2210
# Epoch 75/500
# 614/614 [==============================] - 0s 153us/sample - loss: 4.5624 - y1_output_loss: 1.4784 - y2_output_loss: 3.0473 - y1_output_root_mean_squared_error: 1.2212 - y2_output_root_mean_squared_error: 1.7525 - val_loss: 4.9256 - val_y1_output_loss: 1.3661 - val_y2_output_loss: 3.4995 - val_y1_output_root_mean_squared_error: 1.1828 - val_y2_output_root_mean_squared_error: 1.8779
# Epoch 76/500
# 614/614 [==============================] - 0s 175us/sample - loss: 4.5472 - y1_output_loss: 1.4307 - y2_output_loss: 3.1233 - y1_output_root_mean_squared_error: 1.2012 - y2_output_root_mean_squared_error: 1.7619 - val_loss: 5.0362 - val_y1_output_loss: 1.3911 - val_y2_output_loss: 3.6241 - val_y1_output_root_mean_squared_error: 1.1788 - val_y2_output_root_mean_squared_error: 1.9096
# Epoch 77/500
# 614/614 [==============================] - 0s 158us/sample - loss: 3.9289 - y1_output_loss: 1.1243 - y2_output_loss: 2.7698 - y1_output_root_mean_squared_error: 1.0652 - y2_output_root_mean_squared_error: 1.6716 - val_loss: 4.7269 - val_y1_output_loss: 1.1737 - val_y2_output_loss: 3.4852 - val_y1_output_root_mean_squared_error: 1.1023 - val_y2_output_root_mean_squared_error: 1.8740
# Epoch 78/500
# 614/614 [==============================] - 0s 159us/sample - loss: 4.0182 - y1_output_loss: 1.1541 - y2_output_loss: 2.8415 - y1_output_root_mean_squared_error: 1.0778 - y2_output_root_mean_squared_error: 1.6901 - val_loss: 5.5421 - val_y1_output_loss: 1.3046 - val_y2_output_loss: 4.1336 - val_y1_output_root_mean_squared_error: 1.1627 - val_y2_output_root_mean_squared_error: 2.0470
# Epoch 79/500
# 614/614 [==============================] - 0s 169us/sample - loss: 6.3661 - y1_output_loss: 2.0818 - y2_output_loss: 4.2644 - y1_output_root_mean_squared_error: 1.4492 - y2_output_root_mean_squared_error: 2.0654 - val_loss: 4.9762 - val_y1_output_loss: 1.5360 - val_y2_output_loss: 3.4665 - val_y1_output_root_mean_squared_error: 1.2452 - val_y2_output_root_mean_squared_error: 1.8508
# Epoch 80/500
# 614/614 [==============================] - 0s 153us/sample - loss: 4.0044 - y1_output_loss: 1.1576 - y2_output_loss: 2.8267 - y1_output_root_mean_squared_error: 1.0790 - y2_output_root_mean_squared_error: 1.6853 - val_loss: 4.5027 - val_y1_output_loss: 1.0518 - val_y2_output_loss: 3.4034 - val_y1_output_root_mean_squared_error: 1.0357 - val_y2_output_root_mean_squared_error: 1.8520
# Epoch 81/500
# 614/614 [==============================] - 0s 146us/sample - loss: 3.4321 - y1_output_loss: 0.8973 - y2_output_loss: 2.5385 - y1_output_root_mean_squared_error: 0.9492 - y2_output_root_mean_squared_error: 1.5909 - val_loss: 6.3263 - val_y1_output_loss: 1.4610 - val_y2_output_loss: 4.8055 - val_y1_output_root_mean_squared_error: 1.2277 - val_y2_output_root_mean_squared_error: 2.1953
# Epoch 82/500
# 614/614 [==============================] - 0s 170us/sample - loss: 3.6415 - y1_output_loss: 1.0269 - y2_output_loss: 2.5965 - y1_output_root_mean_squared_error: 1.0179 - y2_output_root_mean_squared_error: 1.6141 - val_loss: 6.3909 - val_y1_output_loss: 1.7505 - val_y2_output_loss: 4.6318 - val_y1_output_root_mean_squared_error: 1.3275 - val_y2_output_root_mean_squared_error: 2.1514
# Epoch 83/500
# 614/614 [==============================] - 0s 151us/sample - loss: 4.4099 - y1_output_loss: 1.1047 - y2_output_loss: 3.2749 - y1_output_root_mean_squared_error: 1.0538 - y2_output_root_mean_squared_error: 1.8164 - val_loss: 5.4860 - val_y1_output_loss: 1.5426 - val_y2_output_loss: 3.7692 - val_y1_output_root_mean_squared_error: 1.2651 - val_y2_output_root_mean_squared_error: 1.9711
# Epoch 84/500
# 614/614 [==============================] - 0s 168us/sample - loss: 3.8685 - y1_output_loss: 1.0616 - y2_output_loss: 2.7951 - y1_output_root_mean_squared_error: 1.0303 - y2_output_root_mean_squared_error: 1.6754 - val_loss: 9.5871 - val_y1_output_loss: 1.6292 - val_y2_output_loss: 7.7919 - val_y1_output_root_mean_squared_error: 1.2996 - val_y2_output_root_mean_squared_error: 2.8104
# Epoch 85/500
# 614/614 [==============================] - 0s 176us/sample - loss: 4.4492 - y1_output_loss: 1.2889 - y2_output_loss: 3.1230 - y1_output_root_mean_squared_error: 1.1401 - y2_output_root_mean_squared_error: 1.7747 - val_loss: 4.8478 - val_y1_output_loss: 1.5001 - val_y2_output_loss: 3.3081 - val_y1_output_root_mean_squared_error: 1.2333 - val_y2_output_root_mean_squared_error: 1.8239
# Epoch 86/500
# 614/614 [==============================] - 0s 161us/sample - loss: 3.4774 - y1_output_loss: 0.9923 - y2_output_loss: 2.4860 - y1_output_root_mean_squared_error: 0.9973 - y2_output_root_mean_squared_error: 1.5757 - val_loss: 6.0022 - val_y1_output_loss: 1.9152 - val_y2_output_loss: 4.1426 - val_y1_output_root_mean_squared_error: 1.3747 - val_y2_output_root_mean_squared_error: 2.0279
# Epoch 87/500
# 614/614 [==============================] - 0s 186us/sample - loss: 3.6348 - y1_output_loss: 0.9561 - y2_output_loss: 2.6892 - y1_output_root_mean_squared_error: 0.9748 - y2_output_root_mean_squared_error: 1.6385 - val_loss: 9.4690 - val_y1_output_loss: 2.3832 - val_y2_output_loss: 7.0655 - val_y1_output_root_mean_squared_error: 1.5578 - val_y2_output_root_mean_squared_error: 2.6537
# Epoch 88/500
# 614/614 [==============================] - 0s 168us/sample - loss: 3.7673 - y1_output_loss: 1.0261 - y2_output_loss: 2.7522 - y1_output_root_mean_squared_error: 1.0163 - y2_output_root_mean_squared_error: 1.6536 - val_loss: 5.1463 - val_y1_output_loss: 1.3528 - val_y2_output_loss: 3.7486 - val_y1_output_root_mean_squared_error: 1.1775 - val_y2_output_root_mean_squared_error: 1.9390
# Epoch 89/500
# 614/614 [==============================] - 0s 168us/sample - loss: 2.9215 - y1_output_loss: 0.6941 - y2_output_loss: 2.2119 - y1_output_root_mean_squared_error: 0.8342 - y2_output_root_mean_squared_error: 1.4919 - val_loss: 4.9055 - val_y1_output_loss: 1.4165 - val_y2_output_loss: 3.4780 - val_y1_output_root_mean_squared_error: 1.1915 - val_y2_output_root_mean_squared_error: 1.8670
# Epoch 90/500
# 614/614 [==============================] - 0s 180us/sample - loss: 3.7047 - y1_output_loss: 1.0305 - y2_output_loss: 2.6638 - y1_output_root_mean_squared_error: 1.0154 - y2_output_root_mean_squared_error: 1.6351 - val_loss: 4.9330 - val_y1_output_loss: 1.0246 - val_y2_output_loss: 3.8177 - val_y1_output_root_mean_squared_error: 1.0301 - val_y2_output_root_mean_squared_error: 1.9677
# Epoch 91/500
# 614/614 [==============================] - 0s 154us/sample - loss: 3.3242 - y1_output_loss: 0.8583 - y2_output_loss: 2.4377 - y1_output_root_mean_squared_error: 0.9302 - y2_output_root_mean_squared_error: 1.5681 - val_loss: 3.8347 - val_y1_output_loss: 1.1748 - val_y2_output_loss: 2.6502 - val_y1_output_root_mean_squared_error: 1.0846 - val_y2_output_root_mean_squared_error: 1.6304
# Epoch 92/500
# 614/614 [==============================] - 0s 160us/sample - loss: 2.9592 - y1_output_loss: 0.8207 - y2_output_loss: 2.2033 - y1_output_root_mean_squared_error: 0.9071 - y2_output_root_mean_squared_error: 1.4616 - val_loss: 6.4927 - val_y1_output_loss: 1.6525 - val_y2_output_loss: 4.9109 - val_y1_output_root_mean_squared_error: 1.2846 - val_y2_output_root_mean_squared_error: 2.2005
# Epoch 93/500
# 614/614 [==============================] - 0s 165us/sample - loss: 3.4637 - y1_output_loss: 0.9635 - y2_output_loss: 2.4849 - y1_output_root_mean_squared_error: 0.9822 - y2_output_root_mean_squared_error: 1.5809 - val_loss: 5.1003 - val_y1_output_loss: 0.9757 - val_y2_output_loss: 4.0520 - val_y1_output_root_mean_squared_error: 1.0048 - val_y2_output_root_mean_squared_error: 2.0226
# Epoch 94/500
# 614/614 [==============================] - 0s 160us/sample - loss: 9.8838 - y1_output_loss: 2.8808 - y2_output_loss: 6.9620 - y1_output_root_mean_squared_error: 1.6991 - y2_output_root_mean_squared_error: 2.6452 - val_loss: 10.3111 - val_y1_output_loss: 1.8867 - val_y2_output_loss: 8.5118 - val_y1_output_root_mean_squared_error: 1.3852 - val_y2_output_root_mean_squared_error: 2.8969
# Epoch 95/500
# 614/614 [==============================] - 0s 164us/sample - loss: 3.3771 - y1_output_loss: 0.9101 - y2_output_loss: 2.4406 - y1_output_root_mean_squared_error: 0.9577 - y2_output_root_mean_squared_error: 1.5684 - val_loss: 4.0968 - val_y1_output_loss: 0.8419 - val_y2_output_loss: 3.2052 - val_y1_output_root_mean_squared_error: 0.9290 - val_y2_output_root_mean_squared_error: 1.7983
# Epoch 96/500
# 614/614 [==============================] - 0s 162us/sample - loss: 3.2107 - y1_output_loss: 0.7531 - y2_output_loss: 2.4446 - y1_output_root_mean_squared_error: 0.8688 - y2_output_root_mean_squared_error: 1.5671 - val_loss: 4.3406 - val_y1_output_loss: 0.9457 - val_y2_output_loss: 3.3166 - val_y1_output_root_mean_squared_error: 0.9904 - val_y2_output_root_mean_squared_error: 1.8329
# Epoch 97/500
# 614/614 [==============================] - 0s 152us/sample - loss: 3.2500 - y1_output_loss: 0.9017 - y2_output_loss: 2.3519 - y1_output_root_mean_squared_error: 0.9436 - y2_output_root_mean_squared_error: 1.5361 - val_loss: 5.2153 - val_y1_output_loss: 1.7803 - val_y2_output_loss: 3.3716 - val_y1_output_root_mean_squared_error: 1.3546 - val_y2_output_root_mean_squared_error: 1.8386
# Epoch 98/500
# 614/614 [==============================] - 0s 176us/sample - loss: 2.8644 - y1_output_loss: 0.7381 - y2_output_loss: 2.1376 - y1_output_root_mean_squared_error: 0.8630 - y2_output_root_mean_squared_error: 1.4559 - val_loss: 6.0115 - val_y1_output_loss: 1.3138 - val_y2_output_loss: 4.7938 - val_y1_output_root_mean_squared_error: 1.1415 - val_y2_output_root_mean_squared_error: 2.1699
# Epoch 99/500
# 614/614 [==============================] - 0s 155us/sample - loss: 2.8814 - y1_output_loss: 0.6783 - y2_output_loss: 2.2020 - y1_output_root_mean_squared_error: 0.8240 - y2_output_root_mean_squared_error: 1.4841 - val_loss: 5.0327 - val_y1_output_loss: 0.8691 - val_y2_output_loss: 4.0907 - val_y1_output_root_mean_squared_error: 0.9494 - val_y2_output_root_mean_squared_error: 2.0326
# Epoch 100/500
# 614/614 [==============================] - 0s 156us/sample - loss: 3.1345 - y1_output_loss: 0.7150 - y2_output_loss: 2.3960 - y1_output_root_mean_squared_error: 0.8487 - y2_output_root_mean_squared_error: 1.5538 - val_loss: 3.2434 - val_y1_output_loss: 0.8425 - val_y2_output_loss: 2.3369 - val_y1_output_root_mean_squared_error: 0.9305 - val_y2_output_root_mean_squared_error: 1.5419
# Epoch 101/500
# 614/614 [==============================] - 0s 177us/sample - loss: 2.8778 - y1_output_loss: 0.5778 - y2_output_loss: 2.2980 - y1_output_root_mean_squared_error: 0.7633 - y2_output_root_mean_squared_error: 1.5150 - val_loss: 5.3033 - val_y1_output_loss: 1.4138 - val_y2_output_loss: 3.9072 - val_y1_output_root_mean_squared_error: 1.1924 - val_y2_output_root_mean_squared_error: 1.9702
# Epoch 102/500
# 614/614 [==============================] - 0s 162us/sample - loss: 2.3978 - y1_output_loss: 0.5694 - y2_output_loss: 1.8114 - y1_output_root_mean_squared_error: 0.7574 - y2_output_root_mean_squared_error: 1.3506 - val_loss: 3.5961 - val_y1_output_loss: 1.0581 - val_y2_output_loss: 2.5775 - val_y1_output_root_mean_squared_error: 1.0330 - val_y2_output_root_mean_squared_error: 1.5903
# Epoch 103/500
# 614/614 [==============================] - 0s 163us/sample - loss: 2.4326 - y1_output_loss: 0.5937 - y2_output_loss: 1.8385 - y1_output_root_mean_squared_error: 0.7695 - y2_output_root_mean_squared_error: 1.3566 - val_loss: 4.8341 - val_y1_output_loss: 1.8404 - val_y2_output_loss: 3.0446 - val_y1_output_root_mean_squared_error: 1.3550 - val_y2_output_root_mean_squared_error: 1.7315
# Epoch 104/500
# 614/614 [==============================] - 0s 167us/sample - loss: 3.4410 - y1_output_loss: 0.7606 - y2_output_loss: 2.6597 - y1_output_root_mean_squared_error: 0.8741 - y2_output_root_mean_squared_error: 1.6362 - val_loss: 3.4866 - val_y1_output_loss: 0.9869 - val_y2_output_loss: 2.4987 - val_y1_output_root_mean_squared_error: 1.0021 - val_y2_output_root_mean_squared_error: 1.5756
# Epoch 105/500
# 614/614 [==============================] - 0s 158us/sample - loss: 2.3312 - y1_output_loss: 0.5880 - y2_output_loss: 1.7729 - y1_output_root_mean_squared_error: 0.7546 - y2_output_root_mean_squared_error: 1.3273 - val_loss: 7.4982 - val_y1_output_loss: 2.9957 - val_y2_output_loss: 4.8794 - val_y1_output_root_mean_squared_error: 1.6934 - val_y2_output_root_mean_squared_error: 2.1519
# Epoch 106/500
# 614/614 [==============================] - 0s 162us/sample - loss: 2.3523 - y1_output_loss: 0.6346 - y2_output_loss: 1.7120 - y1_output_root_mean_squared_error: 0.7953 - y2_output_root_mean_squared_error: 1.3114 - val_loss: 4.9279 - val_y1_output_loss: 1.8298 - val_y2_output_loss: 3.0373 - val_y1_output_root_mean_squared_error: 1.3637 - val_y2_output_root_mean_squared_error: 1.7516
# Epoch 107/500
# 614/614 [==============================] - 0s 166us/sample - loss: 2.8671 - y1_output_loss: 0.7458 - y2_output_loss: 2.1054 - y1_output_root_mean_squared_error: 0.8674 - y2_output_root_mean_squared_error: 1.4542 - val_loss: 4.9813 - val_y1_output_loss: 0.7412 - val_y2_output_loss: 4.1458 - val_y1_output_root_mean_squared_error: 0.8696 - val_y2_output_root_mean_squared_error: 2.0555
# Epoch 108/500
# 614/614 [==============================] - 0s 154us/sample - loss: 2.3537 - y1_output_loss: 0.5500 - y2_output_loss: 1.8182 - y1_output_root_mean_squared_error: 0.7416 - y2_output_root_mean_squared_error: 1.3430 - val_loss: 13.4717 - val_y1_output_loss: 2.2938 - val_y2_output_loss: 11.1434 - val_y1_output_root_mean_squared_error: 1.5320 - val_y2_output_root_mean_squared_error: 3.3353
# Epoch 109/500
# 614/614 [==============================] - 0s 173us/sample - loss: 2.6390 - y1_output_loss: 0.6607 - y2_output_loss: 1.9604 - y1_output_root_mean_squared_error: 0.8165 - y2_output_root_mean_squared_error: 1.4044 - val_loss: 3.3923 - val_y1_output_loss: 0.9689 - val_y2_output_loss: 2.3636 - val_y1_output_root_mean_squared_error: 0.9990 - val_y2_output_root_mean_squared_error: 1.5473
# Epoch 110/500
# 614/614 [==============================] - 0s 159us/sample - loss: 3.1851 - y1_output_loss: 0.7716 - y2_output_loss: 2.4204 - y1_output_root_mean_squared_error: 0.8792 - y2_output_root_mean_squared_error: 1.5531 - val_loss: 4.1310 - val_y1_output_loss: 0.7307 - val_y2_output_loss: 3.3020 - val_y1_output_root_mean_squared_error: 0.8692 - val_y2_output_root_mean_squared_error: 1.8372
# Epoch 111/500
# 614/614 [==============================] - 0s 153us/sample - loss: 2.4679 - y1_output_loss: 0.5422 - y2_output_loss: 1.9174 - y1_output_root_mean_squared_error: 0.7299 - y2_output_root_mean_squared_error: 1.3911 - val_loss: 3.3838 - val_y1_output_loss: 0.9960 - val_y2_output_loss: 2.3239 - val_y1_output_root_mean_squared_error: 1.0141 - val_y2_output_root_mean_squared_error: 1.5347
# Epoch 112/500
# 614/614 [==============================] - 0s 166us/sample - loss: 2.5767 - y1_output_loss: 0.6343 - y2_output_loss: 1.9514 - y1_output_root_mean_squared_error: 0.7970 - y2_output_root_mean_squared_error: 1.3933 - val_loss: 3.5568 - val_y1_output_loss: 0.9794 - val_y2_output_loss: 2.4934 - val_y1_output_root_mean_squared_error: 1.0071 - val_y2_output_root_mean_squared_error: 1.5945
# Epoch 113/500
# 614/614 [==============================] - 0s 147us/sample - loss: 2.3884 - y1_output_loss: 0.5819 - y2_output_loss: 1.8028 - y1_output_root_mean_squared_error: 0.7643 - y2_output_root_mean_squared_error: 1.3432 - val_loss: 5.5037 - val_y1_output_loss: 1.0438 - val_y2_output_loss: 4.5080 - val_y1_output_root_mean_squared_error: 1.0244 - val_y2_output_root_mean_squared_error: 2.1105
# Epoch 114/500
# 614/614 [==============================] - 0s 156us/sample - loss: 2.8793 - y1_output_loss: 0.6889 - y2_output_loss: 2.2166 - y1_output_root_mean_squared_error: 0.8327 - y2_output_root_mean_squared_error: 1.4785 - val_loss: 15.0585 - val_y1_output_loss: 1.4667 - val_y2_output_loss: 13.4462 - val_y1_output_root_mean_squared_error: 1.2321 - val_y2_output_root_mean_squared_error: 3.6797
# Epoch 115/500
# 614/614 [==============================] - 0s 173us/sample - loss: 2.1887 - y1_output_loss: 0.5378 - y2_output_loss: 1.6535 - y1_output_root_mean_squared_error: 0.7313 - y2_output_root_mean_squared_error: 1.2860 - val_loss: 5.6426 - val_y1_output_loss: 1.2863 - val_y2_output_loss: 4.3001 - val_y1_output_root_mean_squared_error: 1.1459 - val_y2_output_root_mean_squared_error: 2.0808
# Epoch 116/500
# 614/614 [==============================] - 0s 157us/sample - loss: 2.2067 - y1_output_loss: 0.4759 - y2_output_loss: 1.7177 - y1_output_root_mean_squared_error: 0.6924 - y2_output_root_mean_squared_error: 1.3143 - val_loss: 5.0797 - val_y1_output_loss: 1.2236 - val_y2_output_loss: 3.9668 - val_y1_output_root_mean_squared_error: 1.1028 - val_y2_output_root_mean_squared_error: 1.9656
# Epoch 117/500
# 614/614 [==============================] - 0s 172us/sample - loss: 2.4390 - y1_output_loss: 0.5777 - y2_output_loss: 1.8582 - y1_output_root_mean_squared_error: 0.7621 - y2_output_root_mean_squared_error: 1.3632 - val_loss: 5.3583 - val_y1_output_loss: 0.6704 - val_y2_output_loss: 4.5873 - val_y1_output_root_mean_squared_error: 0.8283 - val_y2_output_root_mean_squared_error: 2.1615
# Epoch 118/500
# 614/614 [==============================] - 0s 172us/sample - loss: 2.0099 - y1_output_loss: 0.5018 - y2_output_loss: 1.4976 - y1_output_root_mean_squared_error: 0.7093 - y2_output_root_mean_squared_error: 1.2275 - val_loss: 3.1382 - val_y1_output_loss: 0.7533 - val_y2_output_loss: 2.3880 - val_y1_output_root_mean_squared_error: 0.8773 - val_y2_output_root_mean_squared_error: 1.5390
# Epoch 119/500
# 614/614 [==============================] - 0s 149us/sample - loss: 2.4538 - y1_output_loss: 0.5618 - y2_output_loss: 1.8724 - y1_output_root_mean_squared_error: 0.7520 - y2_output_root_mean_squared_error: 1.3742 - val_loss: 4.2061 - val_y1_output_loss: 1.0434 - val_y2_output_loss: 3.0742 - val_y1_output_root_mean_squared_error: 1.0375 - val_y2_output_root_mean_squared_error: 1.7691
# Epoch 120/500
# 614/614 [==============================] - 0s 172us/sample - loss: 2.3058 - y1_output_loss: 0.5359 - y2_output_loss: 1.7687 - y1_output_root_mean_squared_error: 0.7336 - y2_output_root_mean_squared_error: 1.3295 - val_loss: 4.6166 - val_y1_output_loss: 0.8075 - val_y2_output_loss: 3.9479 - val_y1_output_root_mean_squared_error: 0.8956 - val_y2_output_root_mean_squared_error: 1.9531
# Epoch 121/500
# ...
# Epoch 461/500
# 614/614 [==============================] - 0s 168us/sample - loss: 0.4358 - y1_output_loss: 0.1368 - y2_output_loss: 0.2952 - y1_output_root_mean_squared_error: 0.3715 - y2_output_root_mean_squared_error: 0.5457 - val_loss: 1.6678 - val_y1_output_loss: 0.2177 - val_y2_output_loss: 1.5750 - val_y1_output_root_mean_squared_error: 0.4694 - val_y2_output_root_mean_squared_error: 1.2031
# Epoch 462/500
# 614/614 [==============================] - 0s 159us/sample - loss: 0.3766 - y1_output_loss: 0.1213 - y2_output_loss: 0.2578 - y1_output_root_mean_squared_error: 0.3488 - y2_output_root_mean_squared_error: 0.5049 - val_loss: 1.6721 - val_y1_output_loss: 0.2246 - val_y2_output_loss: 1.5369 - val_y1_output_root_mean_squared_error: 0.4748 - val_y2_output_root_mean_squared_error: 1.2028
# Epoch 463/500
# 614/614 [==============================] - 0s 148us/sample - loss: 0.3901 - y1_output_loss: 0.1242 - y2_output_loss: 0.2647 - y1_output_root_mean_squared_error: 0.3533 - y2_output_root_mean_squared_error: 0.5151 - val_loss: 1.4203 - val_y1_output_loss: 0.2251 - val_y2_output_loss: 1.2061 - val_y1_output_root_mean_squared_error: 0.4726 - val_y2_output_root_mean_squared_error: 1.0941
# Epoch 464/500
# 614/614 [==============================] - 0s 155us/sample - loss: 0.3888 - y1_output_loss: 0.1124 - y2_output_loss: 0.2747 - y1_output_root_mean_squared_error: 0.3355 - y2_output_root_mean_squared_error: 0.5256 - val_loss: 1.4488 - val_y1_output_loss: 0.1823 - val_y2_output_loss: 1.2924 - val_y1_output_root_mean_squared_error: 0.4289 - val_y2_output_root_mean_squared_error: 1.1246
# Epoch 465/500
# 614/614 [==============================] - 0s 154us/sample - loss: 0.4172 - y1_output_loss: 0.1317 - y2_output_loss: 0.2879 - y1_output_root_mean_squared_error: 0.3635 - y2_output_root_mean_squared_error: 0.5339 - val_loss: 2.5012 - val_y1_output_loss: 0.3411 - val_y2_output_loss: 2.1259 - val_y1_output_root_mean_squared_error: 0.5900 - val_y2_output_root_mean_squared_error: 1.4674
# Epoch 466/500
# 614/614 [==============================] - 0s 156us/sample - loss: 0.3593 - y1_output_loss: 0.1181 - y2_output_loss: 0.2397 - y1_output_root_mean_squared_error: 0.3445 - y2_output_root_mean_squared_error: 0.4905 - val_loss: 1.5578 - val_y1_output_loss: 0.1720 - val_y2_output_loss: 1.4788 - val_y1_output_root_mean_squared_error: 0.4182 - val_y2_output_root_mean_squared_error: 1.1760
# Epoch 467/500
# 614/614 [==============================] - 0s 163us/sample - loss: 0.4730 - y1_output_loss: 0.1314 - y2_output_loss: 0.3402 - y1_output_root_mean_squared_error: 0.3633 - y2_output_root_mean_squared_error: 0.5839 - val_loss: 1.8550 - val_y1_output_loss: 0.3188 - val_y2_output_loss: 1.5314 - val_y1_output_root_mean_squared_error: 0.5663 - val_y2_output_root_mean_squared_error: 1.2387
# Epoch 468/500
# 614/614 [==============================] - 0s 165us/sample - loss: 0.4189 - y1_output_loss: 0.1301 - y2_output_loss: 0.2969 - y1_output_root_mean_squared_error: 0.3579 - y2_output_root_mean_squared_error: 0.5393 - val_loss: 2.5810 - val_y1_output_loss: 0.2344 - val_y2_output_loss: 2.5465 - val_y1_output_root_mean_squared_error: 0.4830 - val_y2_output_root_mean_squared_error: 1.5322
# Epoch 469/500
# 614/614 [==============================] - 0s 150us/sample - loss: 0.5277 - y1_output_loss: 0.1372 - y2_output_loss: 0.3904 - y1_output_root_mean_squared_error: 0.3705 - y2_output_root_mean_squared_error: 0.6249 - val_loss: 1.7233 - val_y1_output_loss: 0.1986 - val_y2_output_loss: 1.6313 - val_y1_output_root_mean_squared_error: 0.4461 - val_y2_output_root_mean_squared_error: 1.2346
# Epoch 470/500
# 614/614 [==============================] - 0s 160us/sample - loss: 0.5472 - y1_output_loss: 0.1757 - y2_output_loss: 0.3689 - y1_output_root_mean_squared_error: 0.4202 - y2_output_root_mean_squared_error: 0.6088 - val_loss: 1.5118 - val_y1_output_loss: 0.1764 - val_y2_output_loss: 1.3974 - val_y1_output_root_mean_squared_error: 0.4214 - val_y2_output_root_mean_squared_error: 1.1551
# Epoch 471/500
# 614/614 [==============================] - 0s 173us/sample - loss: 0.3576 - y1_output_loss: 0.1156 - y2_output_loss: 0.2442 - y1_output_root_mean_squared_error: 0.3364 - y2_output_root_mean_squared_error: 0.4944 - val_loss: 1.6849 - val_y1_output_loss: 0.2805 - val_y2_output_loss: 1.4770 - val_y1_output_root_mean_squared_error: 0.5336 - val_y2_output_root_mean_squared_error: 1.1833
# Epoch 472/500
# 614/614 [==============================] - 0s 176us/sample - loss: 0.4717 - y1_output_loss: 0.1357 - y2_output_loss: 0.3331 - y1_output_root_mean_squared_error: 0.3689 - y2_output_root_mean_squared_error: 0.5794 - val_loss: 1.6819 - val_y1_output_loss: 0.2334 - val_y2_output_loss: 1.5225 - val_y1_output_root_mean_squared_error: 0.4853 - val_y2_output_root_mean_squared_error: 1.2027
# Epoch 473/500
# 614/614 [==============================] - 0s 178us/sample - loss: 0.5870 - y1_output_loss: 0.1587 - y2_output_loss: 0.4248 - y1_output_root_mean_squared_error: 0.3990 - y2_output_root_mean_squared_error: 0.6541 - val_loss: 1.4677 - val_y1_output_loss: 0.2118 - val_y2_output_loss: 1.3546 - val_y1_output_root_mean_squared_error: 0.4590 - val_y2_output_root_mean_squared_error: 1.1212
# Epoch 474/500
# 614/614 [==============================] - 0s 190us/sample - loss: 0.3369 - y1_output_loss: 0.1067 - y2_output_loss: 0.2294 - y1_output_root_mean_squared_error: 0.3263 - y2_output_root_mean_squared_error: 0.4800 - val_loss: 1.4265 - val_y1_output_loss: 0.1782 - val_y2_output_loss: 1.3184 - val_y1_output_root_mean_squared_error: 0.4249 - val_y2_output_root_mean_squared_error: 1.1162
# Epoch 475/500
# 614/614 [==============================] - 0s 158us/sample - loss: 0.3797 - y1_output_loss: 0.1330 - y2_output_loss: 0.2437 - y1_output_root_mean_squared_error: 0.3660 - y2_output_root_mean_squared_error: 0.4957 - val_loss: 1.4771 - val_y1_output_loss: 0.1986 - val_y2_output_loss: 1.3402 - val_y1_output_root_mean_squared_error: 0.4501 - val_y2_output_root_mean_squared_error: 1.1290
# Epoch 476/500
# 614/614 [==============================] - 0s 164us/sample - loss: 0.3826 - y1_output_loss: 0.1161 - y2_output_loss: 0.2635 - y1_output_root_mean_squared_error: 0.3417 - y2_output_root_mean_squared_error: 0.5156 - val_loss: 1.5465 - val_y1_output_loss: 0.2593 - val_y2_output_loss: 1.3197 - val_y1_output_root_mean_squared_error: 0.5142 - val_y2_output_root_mean_squared_error: 1.1323
# Epoch 477/500
# 614/614 [==============================] - 0s 170us/sample - loss: 0.3513 - y1_output_loss: 0.1102 - y2_output_loss: 0.2404 - y1_output_root_mean_squared_error: 0.3330 - y2_output_root_mean_squared_error: 0.4903 - val_loss: 1.6499 - val_y1_output_loss: 0.2071 - val_y2_output_loss: 1.4474 - val_y1_output_root_mean_squared_error: 0.4537 - val_y2_output_root_mean_squared_error: 1.2017
# Epoch 478/500
# 614/614 [==============================] - 0s 179us/sample - loss: 0.4349 - y1_output_loss: 0.1195 - y2_output_loss: 0.3117 - y1_output_root_mean_squared_error: 0.3470 - y2_output_root_mean_squared_error: 0.5608 - val_loss: 1.3733 - val_y1_output_loss: 0.1758 - val_y2_output_loss: 1.2285 - val_y1_output_root_mean_squared_error: 0.4222 - val_y2_output_root_mean_squared_error: 1.0932
# Epoch 479/500
# 614/614 [==============================] - 0s 158us/sample - loss: 0.5234 - y1_output_loss: 0.1325 - y2_output_loss: 0.3964 - y1_output_root_mean_squared_error: 0.3623 - y2_output_root_mean_squared_error: 0.6262 - val_loss: 1.6302 - val_y1_output_loss: 0.2911 - val_y2_output_loss: 1.4554 - val_y1_output_root_mean_squared_error: 0.5372 - val_y2_output_root_mean_squared_error: 1.1583
# Epoch 480/500
# 614/614 [==============================] - 0s 155us/sample - loss: 0.4500 - y1_output_loss: 0.1243 - y2_output_loss: 0.3234 - y1_output_root_mean_squared_error: 0.3539 - y2_output_root_mean_squared_error: 0.5699 - val_loss: 1.3543 - val_y1_output_loss: 0.1652 - val_y2_output_loss: 1.2354 - val_y1_output_root_mean_squared_error: 0.4057 - val_y2_output_root_mean_squared_error: 1.0907
# Epoch 481/500
# 614/614 [==============================] - 0s 154us/sample - loss: 0.5196 - y1_output_loss: 0.1502 - y2_output_loss: 0.3676 - y1_output_root_mean_squared_error: 0.3878 - y2_output_root_mean_squared_error: 0.6076 - val_loss: 1.4402 - val_y1_output_loss: 0.1684 - val_y2_output_loss: 1.3136 - val_y1_output_root_mean_squared_error: 0.4111 - val_y2_output_root_mean_squared_error: 1.1275
# Epoch 482/500
# 614/614 [==============================] - 0s 154us/sample - loss: 0.4716 - y1_output_loss: 0.1414 - y2_output_loss: 0.3264 - y1_output_root_mean_squared_error: 0.3771 - y2_output_root_mean_squared_error: 0.5740 - val_loss: 1.3686 - val_y1_output_loss: 0.1757 - val_y2_output_loss: 1.2526 - val_y1_output_root_mean_squared_error: 0.4207 - val_y2_output_root_mean_squared_error: 1.0916
# Epoch 483/500
# 614/614 [==============================] - 0s 163us/sample - loss: 0.4225 - y1_output_loss: 0.1326 - y2_output_loss: 0.2872 - y1_output_root_mean_squared_error: 0.3647 - y2_output_root_mean_squared_error: 0.5381 - val_loss: 1.5247 - val_y1_output_loss: 0.1967 - val_y2_output_loss: 1.4090 - val_y1_output_root_mean_squared_error: 0.4462 - val_y2_output_root_mean_squared_error: 1.1513
# Epoch 484/500
# 614/614 [==============================] - 0s 173us/sample - loss: 0.4212 - y1_output_loss: 0.1266 - y2_output_loss: 0.2938 - y1_output_root_mean_squared_error: 0.3566 - y2_output_root_mean_squared_error: 0.5423 - val_loss: 1.7294 - val_y1_output_loss: 0.1877 - val_y2_output_loss: 1.5495 - val_y1_output_root_mean_squared_error: 0.4354 - val_y2_output_root_mean_squared_error: 1.2409
# Epoch 485/500
# 614/614 [==============================] - 0s 156us/sample - loss: 0.3556 - y1_output_loss: 0.1174 - y2_output_loss: 0.2353 - y1_output_root_mean_squared_error: 0.3441 - y2_output_root_mean_squared_error: 0.4870 - val_loss: 1.3074 - val_y1_output_loss: 0.1592 - val_y2_output_loss: 1.1943 - val_y1_output_root_mean_squared_error: 0.4018 - val_y2_output_root_mean_squared_error: 1.0705
# Epoch 486/500
# 614/614 [==============================] - 0s 155us/sample - loss: 0.4414 - y1_output_loss: 0.1432 - y2_output_loss: 0.2952 - y1_output_root_mean_squared_error: 0.3791 - y2_output_root_mean_squared_error: 0.5456 - val_loss: 1.3123 - val_y1_output_loss: 0.1547 - val_y2_output_loss: 1.1955 - val_y1_output_root_mean_squared_error: 0.3952 - val_y2_output_root_mean_squared_error: 1.0752
# Epoch 487/500
# 614/614 [==============================] - 0s 161us/sample - loss: 0.2968 - y1_output_loss: 0.1018 - y2_output_loss: 0.1943 - y1_output_root_mean_squared_error: 0.3205 - y2_output_root_mean_squared_error: 0.4406 - val_loss: 1.2910 - val_y1_output_loss: 0.1503 - val_y2_output_loss: 1.1786 - val_y1_output_root_mean_squared_error: 0.3905 - val_y2_output_root_mean_squared_error: 1.0670
# Epoch 488/500
# 614/614 [==============================] - 0s 172us/sample - loss: 0.3439 - y1_output_loss: 0.1075 - y2_output_loss: 0.2398 - y1_output_root_mean_squared_error: 0.3286 - y2_output_root_mean_squared_error: 0.4857 - val_loss: 2.3274 - val_y1_output_loss: 0.2401 - val_y2_output_loss: 2.0475 - val_y1_output_root_mean_squared_error: 0.4931 - val_y2_output_root_mean_squared_error: 1.4437
# Epoch 489/500
# 614/614 [==============================] - 0s 164us/sample - loss: 0.3604 - y1_output_loss: 0.1121 - y2_output_loss: 0.2454 - y1_output_root_mean_squared_error: 0.3357 - y2_output_root_mean_squared_error: 0.4977 - val_loss: 1.3601 - val_y1_output_loss: 0.1767 - val_y2_output_loss: 1.2325 - val_y1_output_root_mean_squared_error: 0.4224 - val_y2_output_root_mean_squared_error: 1.0870
# Epoch 490/500
# 614/614 [==============================] - 0s 166us/sample - loss: 0.4299 - y1_output_loss: 0.1276 - y2_output_loss: 0.3011 - y1_output_root_mean_squared_error: 0.3575 - y2_output_root_mean_squared_error: 0.5497 - val_loss: 1.7700 - val_y1_output_loss: 0.2238 - val_y2_output_loss: 1.6710 - val_y1_output_root_mean_squared_error: 0.4728 - val_y2_output_root_mean_squared_error: 1.2436
# Epoch 491/500
# 614/614 [==============================] - 0s 158us/sample - loss: 0.4042 - y1_output_loss: 0.1222 - y2_output_loss: 0.2796 - y1_output_root_mean_squared_error: 0.3509 - y2_output_root_mean_squared_error: 0.5301 - val_loss: 1.4175 - val_y1_output_loss: 0.1821 - val_y2_output_loss: 1.2975 - val_y1_output_root_mean_squared_error: 0.4292 - val_y2_output_root_mean_squared_error: 1.1105
# Epoch 492/500
# 614/614 [==============================] - 0s 160us/sample - loss: 0.3632 - y1_output_loss: 0.1124 - y2_output_loss: 0.2479 - y1_output_root_mean_squared_error: 0.3367 - y2_output_root_mean_squared_error: 0.4998 - val_loss: 1.3987 - val_y1_output_loss: 0.1778 - val_y2_output_loss: 1.2578 - val_y1_output_root_mean_squared_error: 0.4210 - val_y2_output_root_mean_squared_error: 1.1052
# Epoch 493/500
# 614/614 [==============================] - 0s 158us/sample - loss: 0.4969 - y1_output_loss: 0.1228 - y2_output_loss: 0.3707 - y1_output_root_mean_squared_error: 0.3509 - y2_output_root_mean_squared_error: 0.6113 - val_loss: 1.3711 - val_y1_output_loss: 0.1914 - val_y2_output_loss: 1.2063 - val_y1_output_root_mean_squared_error: 0.4411 - val_y2_output_root_mean_squared_error: 1.0847
# Epoch 494/500
# 614/614 [==============================] - 0s 171us/sample - loss: 0.4132 - y1_output_loss: 0.1164 - y2_output_loss: 0.2947 - y1_output_root_mean_squared_error: 0.3420 - y2_output_root_mean_squared_error: 0.5442 - val_loss: 1.4859 - val_y1_output_loss: 0.1995 - val_y2_output_loss: 1.3056 - val_y1_output_root_mean_squared_error: 0.4497 - val_y2_output_root_mean_squared_error: 1.1330
# Epoch 495/500
# 614/614 [==============================] - 0s 171us/sample - loss: 0.4197 - y1_output_loss: 0.1233 - y2_output_loss: 0.2944 - y1_output_root_mean_squared_error: 0.3506 - y2_output_root_mean_squared_error: 0.5448 - val_loss: 1.4120 - val_y1_output_loss: 0.1765 - val_y2_output_loss: 1.2741 - val_y1_output_root_mean_squared_error: 0.4238 - val_y2_output_root_mean_squared_error: 1.1101
# Epoch 496/500
# 614/614 [==============================] - 0s 150us/sample - loss: 0.3908 - y1_output_loss: 0.1148 - y2_output_loss: 0.2740 - y1_output_root_mean_squared_error: 0.3393 - y2_output_root_mean_squared_error: 0.5250 - val_loss: 1.4072 - val_y1_output_loss: 0.1436 - val_y2_output_loss: 1.3091 - val_y1_output_root_mean_squared_error: 0.3813 - val_y2_output_root_mean_squared_error: 1.1233
# Epoch 497/500
# 614/614 [==============================] - 0s 149us/sample - loss: 0.4091 - y1_output_loss: 0.1409 - y2_output_loss: 0.2721 - y1_output_root_mean_squared_error: 0.3753 - y2_output_root_mean_squared_error: 0.5179 - val_loss: 2.5071 - val_y1_output_loss: 0.1850 - val_y2_output_loss: 2.2953 - val_y1_output_root_mean_squared_error: 0.4293 - val_y2_output_root_mean_squared_error: 1.5241
# Epoch 498/500
# 614/614 [==============================] - 0s 163us/sample - loss: 0.4785 - y1_output_loss: 0.1306 - y2_output_loss: 0.3491 - y1_output_root_mean_squared_error: 0.3619 - y2_output_root_mean_squared_error: 0.5895 - val_loss: 1.5762 - val_y1_output_loss: 0.1997 - val_y2_output_loss: 1.5086 - val_y1_output_root_mean_squared_error: 0.4471 - val_y2_output_root_mean_squared_error: 1.1731
# Epoch 499/500
# 614/614 [==============================] - 0s 164us/sample - loss: 0.3651 - y1_output_loss: 0.1247 - y2_output_loss: 0.2401 - y1_output_root_mean_squared_error: 0.3525 - y2_output_root_mean_squared_error: 0.4908 - val_loss: 1.6932 - val_y1_output_loss: 0.2809 - val_y2_output_loss: 1.4281 - val_y1_output_root_mean_squared_error: 0.5249 - val_y2_output_root_mean_squared_error: 1.1907
# Epoch 500/500
# 614/614 [==============================] - 0s 157us/sample - loss: 1.3746 - y1_output_loss: 0.3299 - y2_output_loss: 1.0353 - y1_output_root_mean_squared_error: 0.5769 - y2_output_root_mean_squared_error: 1.0207 - val_loss: 1.4763 - val_y1_output_loss: 0.1548 - val_y2_output_loss: 1.3738 - val_y1_output_root_mean_squared_error: 0.3957 - val_y2_output_root_mean_squared_error: 1.1488

# %% [markdown]
# ## Evaluate the Model and Plot Metrics

# %%
# Test the model and print loss and mse for both outputs
loss, Y1_loss, Y2_loss, Y1_rmse, Y2_rmse = model.evaluate(x=norm_test_X, y=test_Y)
print("Loss = {}, Y1_loss = {}, Y1_mse = {}, Y2_loss = {}, Y2_mse = {}".format(loss, Y1_loss, Y1_rmse, Y2_loss, Y2_rmse))
# Out:
# 154/154 [==============================] - 0s 47us/sample - loss: 1.4763 - y1_output_loss: 0.1554 - y2_output_loss: 1.2961 - y1_output_root_mean_squared_error: 0.3957 - y2_output_root_mean_squared_error: 1.1488
# Loss = 1.4763340423633526, Y1_loss = 0.15541653335094452, Y1_mse = 0.39574095606803894, Y2_loss = 1.2961490154266357, Y2_mse = 1.148792028427124

# %%
# Plot the loss and mse
Y_pred = model.predict(norm_test_X)
plot_diff(test_Y[0], Y_pred[0], title='Y1')
plot_diff(test_Y[1], Y_pred[1], title='Y2')
plot_metrics(metric_name='y1_output_root_mean_squared_error', title='Y1 RMSE', ylim=6)
plot_metrics(metric_name='y2_output_root_mean_squared_error', title='Y2 RMSE', ylim=7)
